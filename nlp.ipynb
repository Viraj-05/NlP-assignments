# %% [markdown]
# # Task 1: Conceptual Understanding (Mandatory – Written)
#
# 1. Difference between "Love" and "love" in NLP?
# ans:- In NLP if normalization is not applied "Love" and "love" can be treated as differently. Here "Love" can be represented as a noun and "love" as a common word. that is why text is usually converted to lowercase  during pre processing.
#
# 2. What happens if stopwords are not removed?
# ans. If step words like "the", "is", "and" are not removed the dataset becomes noisy. this impacts the performance of ml models by reducing their ability to focus on important features.
#
# 3. Provide two real-world scenarios where removing stopwords can be harmful.
# ans. 1.Some stepwords can change the entire sentiment of an statement like "i am not a good coder" removing "not" from the sentence can entierly change the meaning of sentence i.e "i am a good coder" which is exactly opposite.
# 2.words which ask questions like "who", "what", "how" are essential to understand users intent.
#
# 4. Explain the difference between stemming and lemmatization.
# ans. In stemming technique it anly removes the prefixes of suffixes in  some cases which my lead to not be a proper word.
# Lemmatization on the othr hand reduces words to their base using linguistic rules or vocublary.
# Lemmatization is more accurate compared to stemming.

# %% [markdown]
# # Task 2:Build Advanced Preprocessing Function

# %%
import re
from collections import Counter

# %%
def preprocess_text(text):
    if text == "" or not isinstance(text, str):
        return [], ""
    
    text = text.lower()
    
    # remove urls
    text = re.sub(r'http\S+', '', text)
    
    # remove numbers
    text = re.sub(r'\d+', '', text)
    
    # remove repeated letters
    text = re.sub(r'(.)\1{2,}', r'\1\1', text)
    
    # remove special characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    # remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    tokens = text.split()
    
    # remove small words except no, not
    tokens = [w for w in tokens if len(w) > 2 or w in ['no', 'not']]
    
    clean_sentence = " ".join(tokens)
    
    return tokens, clean_sentence

# %% [markdown]
# # Task 3: Stress Testing

# %%
sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

# %%
results = []

for text in sentences:
    tokens, clean = preprocess_text(text)
    
    print("Original:", text)
    print("Tokens:", tokens)
    print("Cleaned:", clean)
    print("-"*40)
    
    results.append(tokens)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Cleaned: get free access now
# ----------------------------------------
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'looved', 'this', 'product']
# Cleaned: absolutely looved this product
# ----------------------------------------
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Cleaned: worst service ever
# ----------------------------------------
# Original: Call me at 9876543210
# Tokens: ['call']
# Cleaned: call
# ----------------------------------------
# Original: This is THE best course!!!
# Tokens: ['this', 'the', 'best', 'course']
# Cleaned: this the best course
# ----------------------------------------
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Cleaned: visit now
# ----------------------------------------
# Original: Nooooo this is baaad!!!
# Tokens: ['noo', 'this', 'baad']
# Cleaned: noo this baad
# ...

# %% [markdown]
# # Task 4: Token Analytics

# %%
for i, tokens in enumerate(results):
    if len(tokens) == 0:
        print("No tokens")
        continue
    
    total = len(tokens)
    unique = len(set(tokens))
    avg = sum(len(t) for t in tokens) / total
    
    print(f"Sentence {i+1}")
    print("Total:", total)
    print("Unique:", unique)
    print("Avg Length:", round(avg,2))
    print("-"*30)
# Out:
# Sentence 1
# Total: 4
# Unique: 4
# Avg Length: 4.0
# ------------------------------
# Sentence 2
# Total: 4
# Unique: 4
# Avg Length: 6.75
# ------------------------------
# Sentence 3
# Total: 3
# Unique: 3
# Avg Length: 5.33
# ------------------------------
# Sentence 4
# Total: 1
# Unique: 1
# Avg Length: 4.0
# ------------------------------
# Sentence 5
# Total: 4
# Unique: 4
# Avg Length: 4.25
# ------------------------------
# Sentence 6
# Total: 2
# Unique: 2
# Avg Length: 4.0
# ------------------------------
# Sentence 7
# Total: 3
# Unique: 3
# Avg Length: 3.67
# ------------------------------
# Sentence 8
# Total: 1
# Unique: 1
# Avg Length: 3.0
# ------------------------------
# Sentence 9
# Total: 4
# Unique: 4
# Avg Length: 4.5
# ------------------------------
# Sentence 10
# Total: 4
# Unique: 4
# Avg Length: 4.0
# ------------------------------

# %% [markdown]
# # Analysis Questions
# Q. Which sentence had the most noise?
# ans. Win $$$ now!!! Limited offer!!!
#
# Q. Which sentence retained the most meaningful tokens after cleaning?
# ans. I am not happy with this

# %% [markdown]
# # Task 5: Frequency Analysis

# %%
all_tokens = []

for t in results:
    all_tokens.extend(t)

counter = Counter(all_tokens)

print("Top 10:", counter.most_common(10))
print("Least 5:", counter.most_common()[-5:])
# Out:
# Top 10: [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('looved', 1), ('product', 1), ('worst', 1), ('service', 1)]
# Least 5: [('limited', 1), ('offer', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %% [markdown]
# # Task 6: Build Full Pipeline

# %%
def full_pipeline(text_list):
    all_tokens = []
    clean_sentences = []
    
    for text in text_list:
        tokens, clean = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(clean)
    
    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }

# %% [markdown]
# # Task 7: Error Handling

# %%
print(preprocess_text(""))
print(preprocess_text("😂😂😂"))
print(preprocess_text("123456"))
# Out:
# ([], '')
# ([], '')
# ([], '')
